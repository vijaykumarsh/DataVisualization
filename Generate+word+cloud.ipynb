# %%
#Generate word cloud

#!pip install wordcloud

import wordcloud as wc
import pandas as pd
from wordcloud import WordCloud
import numpy as np
import image as Image
# Out:
# ...
#   Could not find a version that satisfies the requirement PIL (from versions: )
# No matching distribution found for PIL
# You are using pip version 18.0, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
print(data)
# Out:
#       word
# 0    Vijay
# 1  Anamika
# 2  Poochii
# 3  naushin
# 4    meghu

# %%
text=open('G:\\DCU\\Wordcloud Generator\\file.txt').read()
I=int(input('Enter the words you want'))
F=int(input('Enter font size you want'))
wordcloud=WordCloud(max_words=I).generate(text)
# Out:
# Enter the words you want10
# Enter font size you want10

# %%
wordcloud=WordCloud(max_font_size=F).generate(text)
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#!pip install SpeechRecognition
#!pip install pyAudio
import speech_recognition as sr
r=sr.Recognizer()

with sr.Microphone() as src:
    print("How many words you want ")
    a=r.listen(src)
    
    try:
        text=r.recognize_google(a)
        I=int(text)
        print(I)
    except:
        print('Try again')
# Out:
# How many words you want
# 5

# %%
text=open('G:\\DCU\\Wordcloud Generator\\constitution.txt').read()
# I=int(input('Enter the words you want'))
# F=int(input('Enter font size you want'))
wordcloud=WordCloud(max_words=I).generate(text)

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.show()
